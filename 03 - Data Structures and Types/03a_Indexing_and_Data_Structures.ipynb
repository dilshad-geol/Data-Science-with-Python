# %% [markdown]
# # Indexing<a href="#Indexing" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     # make a string
#     a = "Samosa Pakora"
#     a
#
# Out\[1\]:
#
#     'Samosa Pakora'
#
# In \[2\]:
#
#     a[0]
#
# Out\[2\]:
#
#     'S'
#
# In \[3\]:
#
#     a[1]
#
# Out\[3\]:
#
#     'a'
#
# In \[4\]:
#
#     a[2]
#
# Out\[4\]:
#
#     'm'
#
# In \[5\]:
#
#     a[3]
#
# Out\[5\]:
#
#     'o'
#
# In \[6\]:
#
#     #Length of indexes
#     len(a)
#
# Out\[6\]:
#
#     13
#
# In \[7\]:
#
#     a[0:13]
#
# Out\[7\]:
#
#     'Samosa Pakora'
#
# In \[8\]:
#
#     a[8:-3]
#
# Out\[8\]:
#
#     'ak'
#
# ## string methods<a href="#string-methods" class="anchor-link">¶</a>
#
# In \[9\]:
#
#     food = "biryani"
#     food
#
# Out\[9\]:
#
#     'biryani'
#
# In \[10\]:
#
#     food.upper()
#
# Out\[10\]:
#
#     'BIRYANI'
#
# In \[11\]:
#
#     food.capitalize()
#
# Out\[11\]:
#
#     'Biryani'
#
# In \[12\]:
#
#     food.lower()
#
# Out\[12\]:
#
#     'biryani'
#
# In \[13\]:
#
#     len(food)
#
# Out\[13\]:
#
#     7
#
# In \[14\]:
#
#     food.replace("b", "sh")
#
# Out\[14\]:
#
#     'shiryani'
#
# In \[15\]:
#
#     food.split("i")
#
# Out\[15\]:
#
#     ['b', 'ryan', '']
#
# In \[16\]:
#
#     food.count("a")
#
# Out\[16\]:
#
#     1
#
# In \[17\]:
#
#     food.count("i")
#
# Out\[17\]:
#
#     2
#
# In \[18\]:
#
#     food = "I love Biryani, Raita, coke, and Chicken Karahi"
#     food
#
# Out\[18\]:
#
#     'I love Biryani, Raita, coke, and Chicken Karahi'
#
# In \[19\]:
#
#     food.capitalize()
#
# Out\[19\]:
#
#     'I love biryani, raita, coke, and chicken karahi'
#
# In \[20\]:
#
#     food.upper()
#
# Out\[20\]:
#
#     'I LOVE BIRYANI, RAITA, COKE, AND CHICKEN KARAHI'
#
# In \[21\]:
#
#     food.lower()
#
# Out\[21\]:
#
#     'i love biryani, raita, coke, and chicken karahi'
#
# In \[22\]:
#
#     food.replace("a", "A")
#
# Out\[22\]:
#
#     'I love BiryAni, RAitA, coke, And Chicken KArAhi'
#
# In \[23\]:
#
#     food.count("i")
#
# Out\[23\]:
#
#     5
#
# In \[24\]:
#
#     food.count("lo")
#
# Out\[24\]:
#
#     1
#
# In \[25\]:
#
#     food.count("fd")
#
# Out\[25\]:
#
#     0
#
# In \[26\]:
#
#     food.split(",")
#
# Out\[26\]:
#
#     ['I love Biryani', ' Raita', ' coke', ' and Chicken Karahi']
#
# # finding index number in a string<a href="#finding-index-number-in-a-string" class="anchor-link">¶</a>
#
# In \[27\]:
#
#     food = "I love Biryani, Raita, coke, and Chicken Karahi"
#     food
#
# Out\[27\]:
#
#     'I love Biryani, Raita, coke, and Chicken Karahi'
#
# In \[28\]:
#
#     food.find("a")
#
# Out\[28\]:
#
#     11
#
# In \[29\]:
#
#     food.find("K")
#
# Out\[29\]:
#
#     41
