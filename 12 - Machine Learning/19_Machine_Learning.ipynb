# %% [markdown]
# # Chapter No. 12: Machine Learning Introduction
#
# **Machine Learning**: Is basically Data driven decision making process.
# - Tagging objects and photos are clearly a machine learning play.
# - Advertisements are chosed based on previous data through Machine learning.
# - Google:
#   - It analyzes the test of the querry and adjusting the results based on your search history, personal interests, location etc.
# - Online shopping(Daraz.pk vs Alibaba, vs Amazon, vs Ebay) all use MAchine learning algorithms for their better decisions.
#
# **Other Fields using ML:**
# - Disease detection in plants/humans and animals
# - Genetic disturbances and prediction of diseases based on your nutrition intake
# - Bioinformatics
# - Cancer detection with proteomic analysis
# - Selection of best nutrition based on your blood and urine analysis.
# - Fut microbiome
# - Robotics, softwares, engineering works and much more.
# - Self driving, parking etc.
#
#  **Machine Learning is basically DATA DRIVEN(Training), DECISION MAKING(Prediction)**
#
#  ### Data Driven (Training)
# 1. **Data** is collected
# 2. Algorithm **Training** based on that data,
# 3. to make a **Model** that can predict unknown data and help in decision making.
#
# **ML is important to predict hidden insights of data**
#
#  ### Decision Making (Prediction)
# **Model** is used to predict the unknown data and make decisions.
#
# ## What is MAchine Learning?
# - As the name suggests, MAchine Learning allows machines to learn and make decisions smartly.
# - In machine learning, machines can learn from the data provided or their own experience. It depends upon the type of machine learning.
#
# ## Types of MAchin Learning
# > Supervised
# - Works under supervision
# - Teacher teaches
# - Prediction
# - Outcome
#
# > Unsupervised/CLustring
# - No supervision
# - No Teacher teaches
# - Self Learning
# - No labelling of Data
# - Find patterns by itself
#
# > Semi-Supervised
# - Works under supervision or without supervision
# - Some data is labelled most is not
#
# > Reinforcment
# - Hit and Trial Learning
# - Learn from mistakes
# - Reward and punishment rule
# - Prediction based on rewards and punishment
# - Depends on feedback
#
# #### a). Supervised
# - Input data(80%)
# - Training model and learning patterns of data (20%)
# - Prediction on unknown values
# - Output and reports
#
# **Types:**
# - Classification
#   - For categories
# - Regression
#   - For numerical Data
#
# > **Supervised Learning Algorithms**
# - Logistic Regression
# - K-Nearest Neighbors(K-NN)
# - Support Vector Machines(SVM)
# - Kernel SVM
# - NAive Bayes
# - Decision Tree Classification
# - Random Forest Classification
#
# #### b). Un-Supervised/ Clustring
# - Input data(80%)
# - Training model and learning patterns of data(100%)-Clustring
# - Prediction on unknown values
# - Output and reports
#
# > **Un-supervised/Clustring**
# - K-Means Clustring
# - Hierarchical Clustring
# - Probablistic Clustring
#
# #### c). SemiSupervised
# - Input data
# - Training model and learning patterns of data.
# - Prediction on unknown values
# - Output and reports
#
# - *Most of data contains missing values that are predicted and semi supervised learning is used*
# **Some Labelled data and some Unlabelled data**
#
# #### d). Reinforcement
# - Input Data (its not training data)
# - Training and learning patterns of data
# - Reward and Punishment rule
# - Depends on Feedback
#
# > **Reinforcement Learning Algorithms**
# - Model-Free Reinforcement Learning
#   - Policy Optimization
#   - Q- Learning
# - Model-Based Reinforcement Learning
#   - Learn the Model
#   - Given the Model
#
#
# # Assignment Machine Learning ALgorithms
# #### Supervised Learning Algorithms:
# >**Classification**:
#
# A classification problem is when the output variable is a category, such as “red” or “blue” or “disease” and “no disease”.
#
# >**Regression**:
#
# A regression problem is when the output variable is a real value, such as “dollars” or “weight”.
#
# #### Unsupervised Learning Algorithms:
# > **Clustering**:
#
# A clustering problem is where you want to discover the inherent groupings in the data, such as grouping
# customers by purchasing behavior.
#
#
# > **Association**:
#
# An association rule learning problem is where you want to discover rules that describe large portions of your data, such as people that buy X also tend to buy Y.
#
#
# > **K-means**
#
# is a clustering algorithm. It is not used to make predictions, instead it is used to group data.
#
# #### Reinforced Learning
#
# > **Model-based RL**
#
# uses experience to construct an internal model of the transitions and immediate outcomes in the environment. Appropriate actions are then chosen by searching or planning in this world model.
#
#
# > **Model-free RL**
#
# uses experience to learn directly one or both of two simpler quantities (state/ action values or policies) which can achieve the same optimal behavior but without estimation or use of a world model. Given a policy, a state has a value, defined in terms of the future utility that is expected to accrue starting from that state.
