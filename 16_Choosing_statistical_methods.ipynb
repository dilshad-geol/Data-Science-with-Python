# %% [markdown]
# # Python Ka Chilla
# ## Instructor: Dr. Aammar Tufail
# ## Participant: Mr. Dilshad Raza
# # Chapter# No. 09: Chosing Statistical Methods
#
# ## Main Objectives:
# This will enhance your skills:
# - Choosing a right statistical method
# - Do's and dont's of statistics
# - Reliable Results
# - Paper revisions with proof of statistical test (Wh Qs)
# - Making Data Visualization
# - Interpretting results
#
# ## Tests and their types
# |Parametric Tests|Non-Parametric tests|
# |-----|-----|
# |- More Reliable results|- Less reliable|
# |- First we have meet the assumptions|- Calculates the rank of data|
# ||- No need to make assumptions|
#
# Before Starting;
#
# I repeat before starting the data analysis:
#
# ### Step 1: Normality Test
#
# Tests to be used:
# - **Shapiro-Wilk Test**
#       - Specific (Reliable)
# - **Kolmogorov-Smirnov Test**
#       - General (less reliable)
#
# ### Step 2: Homogeneity Test
#
# The variance of the variable in the data are equal
#
# Tests to be used:
# - **Levene`s Test**
#
# ### Step 3: Purpose
#
# Know the **purpose** of your research.
#
# ### Two types of Purposes
# |Comparision|Relationship|
# |-----|-----|
# |- Difference|- Connection|
#
# #### Comparision:
#
# - At least two groups:
#   - Examples:
#     - Male vs Female
#     - Control group vs Treatments group
#     - Grouping individuals by color preference
#
# #### Relationship:
#
# - Find a connection:
#   - Examples:
#       - Can food predict weight of a group of individuals
#       - Do fertilizer application increases crop growth?
# - We seek following:
#   - Connection
#   - Correlation
#   - Causation
#   - Prediction
#  ## Step-4: Data Type
#  Know the TYPE OF DATA you are working with.
#
#  ### Two types of DAta
# |Categorical|Continous|
# |-----|-----|
# |- Qualitative|- Quantitative|
# |- No numerical meaning|- MNumerical|
# |- Represented in text|- Mostly represented in numbers|
# |- e.g. character, factors|- e.g.: Numerical variable, int and float|
#
# #### Categorical Data
# Qualitative:
# - Examples
#   - Yes and No answers
#   - Have you ever been in Lahore?
#   - Which gene was expressed?
#   - Do you like Mangoes?"yes" or "No"
#
# #### Continuos Data
# Quantitative:
# - Examples
#   - Amount
#   - Number
#   - Age
#   - Plant Height
#   - Number of bacterial colonies
#   - Chlorophyll content
#   - Fertilizer Amount
#
# ## Statistical Tests
#
# Choose a statistical test from three main families.
#
# |1|2|3|
# |----|-----|----|
# | Chi-Squared | t-Test/ ANOVA | Correlation |
# |Purpose: Comparision|Purpose: Comparision|Purpose: Relationship|
# |DAta: Categorical only(Chi-Squared)| DAta: Categorical and Continuous(t-test)|Data: Continuous Only|
#
# ### 1- Chi-Squared Tests
# Purpose: Comparision
#
# Data: Categorical only
#
# - Types:
#   - Chi-Squared test of homogeneity
#   - Chi-Squared test if independence
#
# - When to use?
#   - Nothing effects this,
#   - Can be used with any number of levels or groups
#
# **You must remember PUPOSE and DATA TYPE**
#
# ### 2- t-Tests/ANOVA
# Purpose: Comparision
#
# Data: Categorical and Continuous data
#
# When and Where to Use?
# - Types:
#   - **One-sample t-test**:(for one sample group with a know mean)
#   - **Two-sample t-test:**
#     - **Un-paired t-test**:(Two different groups)
#     - **Paired t-Test**: (Same group Twice)
#
#   - **ANOVA(Analysis of Variance)[3+ levels or groups are involved]:**
#     - **One-way ANOVA**:(Even one of group is significant you will get significant results, but doesn't tell you which one;)
#     - **Two-way ANOVA**
#     - **Repeated measures of ANOVA**(3+ paired groups, scale up of paired t-Test)
#
# ### 3- Correlation
# Pupose: Relationship
# Data: continuous only(Correlation)
#
# When and Where to use?
#
# **Types**
# - **Pearson`s Correlation**(one-Independent and One-Dependent variable)
# - **Regression**(one-Independent and one-dependent Variable):
#   - **Correlation:** Tells us how closely connected two variables are? (Is food a predictor of weight gain?)
#   - **Regression:**Tells us a specific mathematical equation that describes the relationship.(This helps us to find the data points not measured yet)**e.g. missing values can be predicted like this!**
#
# ## **Important things**
#
# - YOur data is **Normally distributed**
# - or follow a **Gaussian distribution**
#
# **NON RELIABLE RESULTS**
# Assumptions about your data; these trusts you that:
#
# **If you do not follow the assumptons and break the trusts of 3-test families, they will not happy with you!**
#
# **IF ASSUMPTIONS ARE NOT MET!**
# you have to;
# - check normality or normallize data
#   - Standardization
#   - Min-max scaling
#   - Log transformation
# - Use alternative Non-Parametric Tests
#
# ### NON-PARAMETRIC ALTERNATIVES
#
# |1|2|3|
# |------|-----|------|
# |Chi-Squared|t-test/ANOVA|Correlation|
# ||1- One sample t-test(ONE-SAMPLE WILCOXON SIGNED RANK TEST)|1- Pearson's Correlation(Spearmans's Correlation & Kendall's Tau)|
# |Chi-Squared|2- Two Sample t-Test(Unpaired[Mann Whitney's U-test])|2- Regression|
# ||3- ANOVA(Kruskal-Wallis test)||
#
#
# ## ANOVA(Analysis of Variance)3+ levels or groups are involved:
#   - **One-way ANOVA**:
#       - (Even one of group is significant you will get significant results, but doesn't tell you which one;)
#   - **Two-way ANOVA**
#       - (2-factors involved)
#   - **Repeated measures of ANOVA**
#       - (3+ paired groups, scale up of paired t-Test)
# - **ANCOVA**(Analysis of Co-Variance)
#   - Compare the means of 3+ independent groups which can not be tested by ANOVA because the variables are affected by co-variance(pre-test and post-test of class)
# - **MANOVA**(Multi-variate analysis of Variance)
# - **MANCOVA**(Multi-variate analysis of Co-variance)
#
# ## Some other Tests
# |**Reliability tests**|**Validity tests**|**Sample size computation**|
# |------|------|------|
# |Kunder-Richardson's Formula 20 & 21(KR 20/21)|Krippendorf's Alpha Test|how to make sure how many samples are valid|
# |**Inter-rater Reliability tests**|Fleis's Kappa Test|Cochran's Q Test|
# |Krippendorf's Alpha(categorical or continuous)||Yamane's Test and many others|
# |Fleis's Kappa(Only Categorical)|||
